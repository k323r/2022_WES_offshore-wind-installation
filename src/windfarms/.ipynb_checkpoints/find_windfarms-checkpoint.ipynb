# %%
import cartopy
import glob
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sys

# %matplotlib notebook

sys.path.append("../marinetraffic/")

from vesseltracks import read_vesseltracks_file

# %%
def to_int(string):
    try:
        return int(string)
    except Exception as e:
        print(f'failed to convert to int: {string} {e}')
        return 0
windfarms = pd.read_csv("windfarms.csv")
windfarms.set_index('index', inplace=True)
windfarms.commissioning = windfarms.commissioning.apply(to_int)
# Out:
# failed to convert to int: nan cannot convert float NaN to integer
# failed to convert to int: nan cannot convert float NaN to integer
# failed to convert to int: nan cannot convert float NaN to integer
# failed to convert to int: 1997/2018 invalid literal for int() with base 10: '1997/2018'
# failed to convert to int: — invalid literal for int() with base 10: '—'
# failed to convert to int: — invalid literal for int() with base 10: '—'

# %%
# Out:
# name                                                Global Tech I
# sea                                                     north_sea
# country                                                   germany
# capacity                                                    400.0
# type                  AREVA Multibrid M5000-116 (5.0 MW. 116.0 m)
# number_of_turbines                                           80.0
# coordinates                            54° 30′ 0″ N. 6° 21′ 30″ O
# status                                                 production
# commissioning                                                2015
# sources_remarks                                              [29]
# turbine_capacity                                              5.0
# latitude                                                     54.5
# longitude                                                6.358333
# Name: 53, dtype: object

# %%
def get_cluster_coord_year(basedir):
    for vesseldir in glob.glob(os.path.join(basedir, "*")):
        vesselname = os.path.basename(vesseldir)
        # print(f"processing {vesselname}")
        for clusterdir in glob.glob(os.path.join(vesseldir, "clusters/cluster_*")):
            clustername = os.path.basename(clusterdir)
            # print(f"processing {clustername}")
            if os.path.isfile(cluster_fpath := os.path.join(clusterdir, f"{vesselname}_{clustername}.csv")):
                #print(cluster_fpath)
                cluster = read_vesseltracks_file(cluster_fpath)
                lat_mean = cluster.latitude.mean()
                lon_mean = cluster.longitude.mean()
                year = cluster.index[-1].year
                yield (vesselname, clustername, lat_mean, lon_mean, year)

# %%
def match_cluster_windfarm(clustered_vesseltracks_dir, windfarms, lower_bound=0.05, upper_bound=0.05, verbose=False):
    for (vesselname, clustername, cluster_lat, cluster_lon, cluster_year) in get_cluster_coord_year(clustered_vesseltracks_dir):
        for windfarm in windfarms.itertuples():
            #print(windfarm)
            #print(windfarm["name"], windfarm.latitude, windfarm.longitude)
            lat_lower = windfarm.latitude - lower_bound
            lat_upper = windfarm.latitude + upper_bound
            lon_lower = windfarm.longitude - lower_bound
            lon_upper = windfarm.longitude + upper_bound
            if lat_lower < cluster_lat < lat_upper and lon_lower < cluster_lon < lon_upper and cluster_year <= windfarm.commissioning:
                if verbose:
                    print(f"found possible match: {windfarm.Index} {windfarm.name}: {vesselname}/{clustername}")
                yield (windfarm.Index, windfarm.name, vesselname, clustername, cluster_lat, cluster_lon)

# %%
matching_windfarms = pd.DataFrame(data=match_cluster_windfarm("../../data/marinetraffic/clustered/", windfarms, verbose=True), columns=["windfarm_index", "windfarm_name", "vesselname", "clustername", "cluster_lat", "cluster_lon"])
matching_windfarms.index.name = 'index'
# Out:
# found possible match: 49 Northwind: 246777000_mpi-resolution/cluster_4
# found possible match: 79 Rentel: 246777000_mpi-resolution/cluster_4
# found possible match: 93 Kaskasi: 246777000_mpi-resolution/cluster_18
# found possible match: 64 Nordergründe: 246777000_mpi-resolution/cluster_7
# found possible match: 44 Lincs: 246777000_mpi-resolution/cluster_1
# found possible match: 54 Humber Gateway: 246777000_mpi-resolution/cluster_5
# found possible match: 263 Beleolico *: 246777000_mpi-resolution/cluster_19
# found possible match: 91 Moray Firth (East): 215644000_blue-tern/cluster_4
# found possible match: 88 Borssele (Phasen 3 und 4): 215644000_blue-tern/cluster_2
# found possible match: 139 Wikinger: 229044000_brave-tern/cluster_4
# found possible match: 28 Walney (Phasen 3 und 4): 229044000_brave-tern/cluster_8
# found possible match: 76 Hohe See: 229044000_brave-tern/cluster_2
# found possible match: 70 Galloper: 229080000_bold-tern/cluster_9
# found possible match: 74 Borkum Riffgrund (Phasen 1 und 2): 229080000_bold-tern/cluster_11
# found possible match: 67 Veja Mate: 229080000_bold-tern/cluster_8
# found possible match: 53 Global Tech I: 229080000_bold-tern/cluster_3
# found possible match: 80 Albatros (Hohe See Extension): 229080000_bold-tern/cluster_3
# found possible match: 66 Sandbank (Phase 1): 245924000_mpi-adventure/cluster_11
# found possible match: 93 Kaskasi: 245924000_mpi-adventure/cluster_6
# found possible match: 45 Teesside *: 245924000_mpi-adventure/cluster_3
# found possible match: 137 EnBW Baltic 2: 218657000_vole-au-vent/cluster_1
# found possible match: 63 Nobelwind (Bligh Bank Phase 2): 218657000_vole-au-vent/cluster_5
# found possible match: 141 Kriegers Flak: 253366000_vole-au-vent/cluster_9
# found possible match: 74 Borkum Riffgrund (Phasen 1 und 2): 253366000_vole-au-vent/cluster_4
# found possible match: 156 Coastal Virginia (Demonstrator): 253366000_vole-au-vent/cluster_7
# found possible match: 81 Borssele (Phasen 1 und 2): 219019002_sea-challenger/cluster_11
# found possible match: 78 Merkur Offshore: 219019002_sea-challenger/cluster_7
# found possible match: 60 Dudgeon: 219019002_sea-challenger/cluster_6
# found possible match: 140 Arkona-Becken Südost: 219019002_sea-challenger/cluster_10
# found possible match: 78 Merkur Offshore: 235090598_blue-tern/cluster_7
# found possible match: 87 Trianel Windpark Borkum (Phasen 1 und 2): 235090598_blue-tern/cluster_13
# found possible match: 76 Hohe See: 235090598_blue-tern/cluster_10
# found possible match: 137 EnBW Baltic 2: 218389000_thor/cluster_9
# found possible match: 85 Northwester 2: 218389000_thor/cluster_18
# found possible match: 86 Seamade (Zonen Mermaid und Seastar): 218389000_thor/cluster_18
# found possible match: 93 Kaskasi: 218389000_thor/cluster_7
# found possible match: 93 Kaskasi: 218389000_thor/cluster_12
# found possible match: 80 Albatros (Hohe See Extension): 218389000_thor/cluster_5
# found possible match: 56 Meerwind Süd/Ost: 218389000_thor/cluster_6
# found possible match: 57 Nordsee Ost: 218389000_thor/cluster_6
# found possible match: 82 East Anglia ONE: 218389000_thor/cluster_17
# found possible match: 78 Merkur Offshore: 218389000_thor/cluster_3
# found possible match: 43 BARD Offshore I: 218389000_thor/cluster_2
# found possible match: 4 Baie de Saint-Brieuc: 245179000_aeolus/cluster_9
# found possible match: 84 Norther: 245179000_aeolus/cluster_8
# found possible match: 61 Gemini: 245179000_aeolus/cluster_5
# found possible match: 88 Borssele (Phasen 3 und 4): 245179000_aeolus/cluster_3
# found possible match: 55 Luchterduinen: 245179000_aeolus/cluster_2

# %%
windfarms.loc[49]
# Out:
# name                                          Northwind
# sea                                           north_sea
# country                                         belgium
# capacity                                          216.0
# type                  Vestas V112-3.0 (3.0 MW. 112.0 m)
# number_of_turbines                                 72.0
# coordinates                   51° 37′ 0″ N. 2° 54′ 0″ O
# status                                       production
# commissioning                                      2014
# sources_remarks                                    [24]
# turbine_capacity                                    3.0
# latitude                                      51.616667
# longitude                                           2.9
# Name: 49, dtype: object

# %%
def plot_cluster(
    vessel_tracks: pd.DataFrame,
    windfarm, 
    title : str = "",
    label : str = "",
    margin : float = 0.1,
    figsize : tuple =(9, 9),
    save_fig="",
    verbose=False,
    transparent=True,
    show_fig=False,
):
    figure = plt.figure(figsize=figsize)
    if transparent:
        figure.patch.set_alpha(0)
    min_lat = vessel_tracks.latitude.min() - margin
    max_lat = vessel_tracks.latitude.max() + margin
    min_lon = vessel_tracks.longitude.min() - margin
    max_lon = vessel_tracks.longitude.max() + margin
    if verbose:
        print(
            f"min_lat: {min_lat} min_lon: {min_lon} max_lat: {max_lat} max_lon: {max_lon}"
        )
    ax = figure.add_subplot(1,1,1, projection=cartopy.crs.Mercator())
    ax.set_extent([min_lon, max_lon, min_lat, max_lat])
    ax.add_feature(cartopy.feature.BORDERS)
    ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
    ax.coastlines(resolution='10m')
    plt.scatter(vessel_tracks['longitude'], vessel_tracks['latitude'], transform=cartopy.crs.PlateCarree(), label=label)
    plt.scatter(windfarm.longitude, windfarm.latitude, color='tab:red', transform=cartopy.crs.PlateCarree(), label=windfarm["name"])
    plt.scatter(vessel_tracks.longitude.mean(), vessel_tracks.latitude.mean(), transform=cartopy.crs.PlateCarree(), label="vessel tracks centroid", color='tab:green')
    print(vessel_tracks.longitude.mean(), vessel_tracks.latitude.mean())
    plt.legend()
    if title:
        plt.title(title)
    plt.tight_layout()
    if save_fig:
        plt.savefig(save_fig, dpi=300)
    if show_fig:
        plt.show()

# %%
basedir = "../../data/marinetraffic/clustered/"
for _, matching_windfarm in matching_windfarms.iterrows():
    clusterpath = os.path.join(os.path.join(os.path.join(basedir, matching_windfarm.vesselname), f"clusters/{matching_windfarm.clustername}"), f"{matching_windfarm.vesselname}_{matching_windfarm.clustername}.csv")
    if not os.path.isfile(clusterpath):
        print(f"no such file or directory: {clusterpath}")
    cluster = pd.read_csv(clusterpath)
    plot_cluster(cluster, windfarms.loc[matching_windfarm.windfarm_index], label=f'{matching_windfarm.vesselname} {matching_windfarm.clustername}', show_fig=True)
# Out:
# <img src="data:image/png;base64,..." width="900">
# 2.9020094743970923 51.62111845391476
# <img src="data:image/png;base64,..." width="900">
# 2.9020094743970923 51.62111845391476
# <img src="data:image/png;base64,..." width="900">
# 7.734111003003003 54.452532102102104
# <img src="data:image/png;base64,..." width="900">
# 8.179698293137255 53.82315147058823
# <img src="data:image/png;base64,..." width="900">
# 0.4932723243125905 53.18605778581765
# <img src="data:image/png;base64,..." width="900">
# 0.29638149697692917 53.6436418005834
# <img src="data:image/png;base64,..." width="900">
# 17.153550052117264 40.49959723127036
# <img src="data:image/png;base64,..." width="900">
# -2.7033957338975085 58.15919898918664
# <img src="data:image/png;base64,..." width="900">
# 2.9417558974358977 51.69850384615385
# <img src="data:image/png;base64,..." width="900">
# 14.047759708580681 54.840417463572585
# <img src="data:image/png;base64,..." width="900">
# -3.744912893203884 54.11794441747573
# <div id='32652857-5580-483e-89d6-c0f9bd995eac'></div>
# 6.275348744549419 54.44996712209303
# <div id='2f664a20-41a9-460c-bf48-b99f166daf5a'></div>
# 2.067811296829971 51.914191440922195
# <div id='e434bbc4-a4ab-4495-86f8-0772f6325125'></div>
# 6.5023481145833335 53.951454479166664
# <div id='18a2d25a-6e00-411a-982e-4312175ba707'></div>
# 5.873987153061225 54.326712431972794
# <div id='9a25137d-17a4-4ec5-bb00-ea6b42f7e8fe'></div>
# 6.369831538310413 54.51064332023575
# <div id='02bf60ef-77f4-439e-84da-d9be5aa2daf9'></div>
# 6.369831538310413 54.51064332023575
# <div id='d6f0e075-b256-479d-8af1-064ad18c92c3'></div>
# 6.847074397830019 55.208180765521405
# <div id='a8f3386b-c5d8-497a-b930-81632b61aedf'></div>
# 7.700167464935065 54.51864
# <div id='c2d6222c-09c0-4170-b875-ba23d2aa4e08'></div>
# -1.093048410798122 54.644194295774646
# /tmp/ipykernel_403011/2406122249.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   figure = plt.figure(figsize=figsize)
# <div id='4c9568e4-c587-41a2-a5cb-1ea9a4d41d71'></div>
# 13.15688964661654 54.97279441353383
# <div id='b8d7c98f-e349-4f11-b84b-533ce09b97ad'></div>
# 2.811856316266425 51.66888570457635
# <div id='d6388fdb-ec6a-488e-8dfb-fdfefcc8069a'></div>
# 12.929760398335315 55.0280316765755
# <div id='3f693960-4c9a-470c-a72d-af3eebac4f68'></div>
# 6.516667918560605 53.95420145833334
# <div id='48546a32-07c8-4f21-adff-d115aeac4f4b'></div>
# -75.49228681992338 36.89085137931034
# <div id='7e5fec67-d5ca-40a3-b2b8-931fa32b2949'></div>
# 3.063396044126787 51.70114293971411
# <div id='3b65abd4-aa02-4035-9583-450ff279df80'></div>
# 6.557355207171315 54.034739641434264
# <div id='08926d38-1910-4713-9c0b-079b4ea85088'></div>
# 1.3804933311627907 53.261560604651166
# <div id='3e867e0a-29a5-4ade-944f-623191bb9559'></div>
# 14.12013025462963 54.78368041666667
# <div id='9bb76e89-792f-4313-bf7a-4175d5daee6d'></div>
# 6.5492287037964125 54.03761958281185
# <div id='e6d6e00a-b88e-49bc-97f5-61f503e7d14a'></div>
# 6.434286320205479 54.040182465753425
# <div id='29787ece-4211-4eb2-b675-ecd44ed6d4dd'></div>
# 6.323666218259629 54.4394955064194
# <div id='304a80d8-643e-478c-81ad-48d160f11455'></div>
# 13.159989462151396 54.97231603585657
# <div id='19424630-dd59-476e-b829-1379b3e809d1'></div>
# 2.7242134029850744 51.71287782089552
# <div id='2022202f-0e90-4cf4-8255-ac7cda17aee7'></div>
# 2.7242134029850744 51.71287782089552
# <div id='b20225ee-2c89-41ae-887e-c0920ecda64b'></div>
# 7.73415453015873 54.52070565079365
# <div id='300b1b3f-c602-48e1-8406-a2c389c408c7'></div>
# 7.674543249858356 54.44886342776204
# <div id='23bdd2e5-f208-4ee1-b6c9-4d7163bf562d'></div>
# 6.377868824884793 54.48003622119816
# <div id='33021522-a89d-49ab-bcbc-632e37555b8e'></div>
# 7.70029647933071 54.40005678149606
# <div id='f16ac96f-40e6-4cc4-b0e3-c4dc1f10e8ee'></div>
# 7.70029647933071 54.40005678149606
# <div id='80da7734-dac5-4a62-82a2-5c4bb7bf874f'></div>
# 2.500724320557491 52.21420029616725
# <div id='afec8221-9486-4cc2-ab6b-c02eff898b50'></div>
# 6.569447949462678 54.03170790589602
# <div id='02c2b1d3-8646-4a51-8c97-3cc4d428fba0'></div>
# 5.987476652653928 54.33760694267516
# <div id='04489c0c-8e8a-415a-8a6b-06d8e68edfe0'></div>
# -2.556726715077605 48.86887309682188
# <div id='7cae1c3d-5005-4e16-a5fa-9c6abacc7b64'></div>
# 3.009912370098039 51.524634852941176
# <div id='3a920be6-8860-498c-8b89-9cf8c2b2d9df'></div>
# 5.973997713690477 54.03551386904762
# <div id='c65ea7d4-4c77-44b2-9a8c-c52371f6a89e'></div>
# 2.9317094823008847 51.70916120733249
# <div id='ac02d878-23d4-41ea-9a6c-bc8f69520098'></div>
# 4.164911682539683 52.405141807081804
