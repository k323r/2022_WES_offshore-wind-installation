# %% [markdown]
# # Vessel Data available from marinetraffic.com
#
# In this notebook the sanitized vessel track data from marinetraffic.com is visualy inspected. Data is located in `data/marine-traffic/sanitized` in the form of csv data files

# %%
# load dependecies
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from os import path
from mpl_toolkits.basemap import Basemap
from config import VESSEL_NAMES
from plot_mtdata import plot_track

# make plots interactive
# %matplotlib notebook

# %reload_ext autoreload
# %autoreload 2

# %%
vessels = dict()
for vessel_file in glob(path.join('../../data/marine-traffic/sanitized/*.csv')):
    print(f'processing file {vessel_file}')
    vessel = vessel_file.split('/')[-1].split('.')[0]
    vessels[vessel] = pd.read_csv(vessel_file)
# Out:
# processing file ../../data/marine-traffic/sanitized/235090598_blue-tern.csv
# processing file ../../data/marine-traffic/sanitized/245924000_mpi-adventure.csv
# processing file ../../data/marine-traffic/sanitized/219019002_sea-challenger.csv
# processing file ../../data/marine-traffic/sanitized/253609000_taillevent.csv
# processing file ../../data/marine-traffic/sanitized/253366000_vole-au-vent.csv
# processing file ../../data/marine-traffic/sanitized/246777000_mpi-resolution.csv
# processing file ../../data/marine-traffic/sanitized/245179000_aeolus.csv
# processing file ../../data/marine-traffic/sanitized/229080000_bold-tern.csv
# processing file ../../data/marine-traffic/sanitized/215644000_blue-tern.csv
# processing file ../../data/marine-traffic/sanitized/229044000_brave-tern.csv
# processing file ../../data/marine-traffic/sanitized/218657000_vole-au-vent.csv
# processing file ../../data/marine-traffic/sanitized/218389000_thor.csv

# %%
for vessel, data in vessels.items():
    print(vessel)
    try:
        plot_track(data, vessel)
    except Exception as e:
        print(f'failed to plot data for vessel {vessel}: {e}')
# Out:
# 235090598_blue-tern
# <img src="data:image/png;base64,..." width="900">
# 245924000_mpi-adventure
# <img src="data:image/png;base64,..." width="900">
# 219019002_sea-challenger
# <img src="data:image/png;base64,..." width="900">
# failed to plot data for vessel 219019002_sea-challenger: 'vertices' must be 2D with shape (M, 2). Your input has shape (0,).
# 253609000_taillevent
# <img src="data:image/png;base64,..." width="900">
# 253366000_vole-au-vent
# <img src="data:image/png;base64,..." width="900">
# failed to plot data for vessel 253366000_vole-au-vent: 'vertices' must be 2D with shape (M, 2). Your input has shape (0,).
# 246777000_mpi-resolution
# <img src="data:image/png;base64,..." width="900">
# failed to plot data for vessel 246777000_mpi-resolution: 'vertices' must be 2D with shape (M, 2). Your input has shape (0,).
# 245179000_aeolus
# <img src="data:image/png;base64,..." width="900">
# failed to plot data for vessel 245179000_aeolus: 'vertices' must be 2D with shape (M, 2). Your input has shape (0,).
# 229080000_bold-tern
# <img src="data:image/png;base64,..." width="900">
# failed to plot data for vessel 229080000_bold-tern: 'vertices' must be 2D with shape (M, 2). Your input has shape (0,).
# 215644000_blue-tern
# <img src="data:image/png;base64,..." width="900">
# 229044000_brave-tern
# <img src="data:image/png;base64,..." width="900">
# failed to plot data for vessel 229044000_brave-tern: 'vertices' must be 2D with shape (M, 2). Your input has shape (0,).
# 218657000_vole-au-vent
# <img src="data:image/png;base64,..." width="900">
# 218389000_thor
# <img src="data:image/png;base64,..." width="900">
# failed to plot data for vessel 218389000_thor: 'vertices' must be 2D with shape (M, 2). Your input has shape (0,).

# %%
(vessels['219019002_sea-challenger'].longitude < 0).any()
# Out:
# True
