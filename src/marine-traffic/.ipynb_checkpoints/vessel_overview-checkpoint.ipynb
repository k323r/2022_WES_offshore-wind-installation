# %%
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from os import path
from mpl_toolkits.basemap import Basemap
from config import VESSEL_NAMES

# %matplotlib notebook

# %%
vessels = dict()
for vessel_file in glob(path.join('../../data/marine-traffic/sanitized/*.csv')):

# %%
blue_tern = pd.read_csv('../../data/marine-traffic/sanitized/215644000_blue-tern.csv')
blue_tern.set_index('epoch', inplace=True)

# %%
blue_tern
# Out:
#                            latitude  longitude  speed  heading  course  \
# epoch
# 2020-06-15 13:52:10+00:00  53.45238   6.819260    0.0    287.0   132.0
# 2020-06-15 14:13:11+00:00  53.45235   6.819262    0.0    287.0   132.0
# 2020-06-15 15:16:12+00:00  53.45241   6.819257    0.0    287.0   132.0
# 2020-06-15 16:19:15+00:00  53.45244   6.819250    0.0    287.0   132.0
# 2020-06-15 17:07:18+00:00  53.45231   6.819145    0.0    287.0   132.0
# ...                             ...        ...    ...      ...     ...
# 2021-11-18 12:00:30+00:00  55.46554  10.526910    0.0    214.0   257.0
# 2021-11-18 13:03:34+00:00  55.46567  10.526790    0.0    214.0   257.0
# 2021-11-18 14:06:27+00:00  55.46561  10.527130    0.0    214.0   257.0
# 2021-11-18 15:09:32+00:00  55.46563  10.527070    0.0    214.0   242.0
# 2021-11-18 16:15:32+00:00  55.46559  10.526930    0.0    214.0   242.0
#
#                            status   timestamp
# epoch
# 2020-06-15 13:52:10+00:00       5  1592229130
# ...

# %%
plt.figure()
plt.scatter(blue_tern.longitude, blue_tern.latitude)

# %%
# create new figure, axes instances.
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
# setup mercator map projection.
m = Basemap(llcrnrlon=-6.,
            llcrnrlat=49.,
            urcrnrlon=13.,
            urcrnrlat=59.,
            rsphere=(6378137.00,6356752.3142),
            resolution='h',
            projection='merc',
            lat_0=50.,
            lon_0=6.,
            lat_ts=20.
           )

m.drawcoastlines()
m.fillcontinents()
# draw parallels
m.drawparallels(np.arange(10,90,20),labels=[1,1,0,1])
# draw meridians
m.drawmeridians(np.arange(-180,180,30),labels=[1,1,0,1])

lons, lats = m(blue_tern.longitude, blue_tern.latitude)

m.scatter(lons, lats, marker = 'o', color='r', zorder=5)

#m.plot(blue_tern.latitude, blue_tern.longitude)

ax.set_title('Blue Tern')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
